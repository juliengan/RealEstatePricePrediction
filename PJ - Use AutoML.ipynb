# %% [markdown]
# # Use Automated Machine Learning
#
# There are many kinds of machine learning algorithm that you can use to train a model, and sometimes it's not easy to determine the most effective algorithm for your particular data and prediction requirements. Additionally, you can significantly affect the predictive performance of a model by preprocessing the training data, using techniques such as normalization, missing feature imputation, and others. In your quest to find the *best* model for your requirements, you may need to try many combinations of algorithms and preprocessing transformations; which takes a lot of time and compute resources.
#
# Azure Machine Learning enables you to automate the comparison of models trained using different algorithms and preprocessing options. You can use the visual interface in [Azure Machine Learning studio](https://ml/azure.com) or the SDK to leverage this capability. The SDK gives you greater control over the settings for the automated machine learning experiment, but the visual interface is easier to use.
#
# ## Before you start
#
# In addition to the latest version of the **azureml-sdk** and **azureml-widgets** packages, you'll need the **azureml-train-automl** package to run the code in this notebook. Run the cell below to verify that it is installed.

# %%
# !pip show azureml-train-automl
# Out:
# Name: azureml-train-automl
# Version: 1.38.0
# Summary: Used for automatically finding the best machine learning model and its parameters.
# Home-page: https://docs.microsoft.com/python/api/overview/azure/ml/?view=azure-ml-py
# Author: Microsoft Corp
# Author-email: None
# License: https://aka.ms/azureml-sdk-license
# Location: /anaconda/envs/azureml_py36/lib/python3.6/site-packages
# Requires: azureml-train-automl-runtime, azureml-train-automl-client, azureml-automl-runtime, azureml-dataset-runtime, azureml-automl-core
# Required-by: azureml-automl-dnn-nlp

# %% [markdown]
# ## Connect to your workspace
#
# With the required SDK packages installed, now you're ready to connect to your workspace.
#
# > **Note**: If you haven't already established an authenticated session with your Azure subscription, you'll be prompted to authenticate by clicking a link, entering an authentication code, and signing into Azure.

# %%
import azureml.core
from azureml.core import Workspace

# Load the workspace from the saved config file
ws = Workspace.from_config()
print('Ready to use Azure ML {} to work with {}'.format(azureml.core.VERSION, ws.name))
# Out:
# Ready to use Azure ML 1.38.0 to work with machinelearningfinal

# %% [markdown]
# ## Prepare data
#
# You don't need to create a training script for automated machine learning, but you do need to load the training data. In this case, you'll use a dataset containing details of diabetes patients, and then split this into two datasets: one for training, and another for model validation.

# %%
from azureml.core import Dataset

default_ds = ws.get_default_datastore()

if 'house prices dataset' not in ws.datasets:
    default_ds.upload_files(files=['./data/over 5 years.csv'], # Upload the diabetes csv files in /data
                        target_path='house-data/', # Put it in a folder path in the datastore
                        overwrite=True, # Replace existing files of the same name
                        show_progress=True)

    #Create a tabular dataset from the path on the datastore (this may take a short while)
    tab_data_set = Dataset.Tabular.from_delimited_files(path=(default_ds, 'house-data/*.csv'))

    # Register the tabular dataset
    try:
        tab_data_set = tab_data_set.register(workspace=ws, 
                                name='house prices dataset',
                                description='house data',
                                tags = {'format':'CSV'},
                                create_new_version=True)
        print('Dataset registered.')
    except Exception as ex:
        print(ex)
else:
    print('Dataset already registered.')


# Split the dataset into training and validation subsets
house_ds = ws.datasets.get("house prices dataset")
train_ds, test_ds = house_ds.random_split(percentage=0.7, seed=123)
print("Data ready!")
# Out:
# Dataset already registered.
# Data ready!

# %% [markdown]
# ## Prepare compute
#
# One of the benefits of cloud compute is that it scales on-demand, enabling you to provision enough compute resources to process multiple child-runs of an automated machine learning experiment in parallel.
#
# Use the following code to specify an Azure Machine Learning compute cluster (it will be created if it doesn't already exist)..
#
# > **Important**: Change *your-compute-cluster* to the name of your compute cluster in the code below before running it! Cluster names must be globally unique names between 2 to 16 characters in length. Valid characters are letters, digits, and the - character.

# %%
from azureml.core.compute import ComputeTarget, AmlCompute
from azureml.core.compute_target import ComputeTargetException

cluster_name = "your-compute-cluster"

try:
    # Check for existing compute target
    training_cluster = ComputeTarget(workspace=ws, name=cluster_name)
    print('Found existing cluster, use it.')
except ComputeTargetException:
    # If it doesn't already exist, create it
    try:
        compute_config = AmlCompute.provisioning_configuration(vm_size='STANDARD_DS11_V2', max_nodes=2)
        training_cluster = ComputeTarget.create(ws, cluster_name, compute_config)
        training_cluster.wait_for_completion(show_output=True)
    except Exception as ex:
        print(ex)
# Out:
# Found existing cluster, use it.

# %% [markdown]
# > **Note**: Compute instances and clusters are based on standard Azure virtual machine images. For this exercise, the *Standard_DS11_v2* image is recommended to achieve the optimal balance of cost and performance. If your subscription has a quota that does not include this image, choose an alternative image; but bear in mind that a larger image may incur higher cost and a smaller image may not be sufficient to complete the tasks. Alternatively, ask your Azure administrator to extend your quota.
#
# ## Configure automated machine learning
#
# Now you're ready to configure the automated machine learning experiment.
#
# One of the most important configuration settings is the metric by which model performance should be evaluated. You can retrieve a list of the metrics that are calculated by automated machine learning for a particular type of model task (classification or regression) like this:

# %%
import azureml.train.automl.utilities as automl_utils

for metric in automl_utils.get_primary_metrics('regression'):
    print(metric)
# Out:
# normalized_mean_absolute_error
# normalized_root_mean_squared_error
# spearman_correlation
# r2_score

# %% [markdown]
# Having decided the metric you want to optimize (in this example, *AUC_weighted*), you can configure the automated machine learning run. To do this, you'll need an AutoML configuration that specifies the target metric as well as options like the data to use, how many combinations to try, and so on.
#
# > **Note**: In this example, you'll restrict the experiment to 4 iterations to reduce the amount of time taken. In reality, you'd likely try many more iterations.

# %%
from azureml.train.automl import AutoMLConfig
automl_settings = {
    "iteration_timeout_minutes": 10,
    "experiment_timeout_hours": 0.3,
    "enable_early_stopping": True,
    "primary_metric": 'spearman_correlation',
    "featurization": 'auto',
    "verbosity": logging.INFO,
    "n_cross_validations": 5
}
automl_config = AutoMLConfig(name='Automated ML Experiment',
                             task='regression',
                             compute_target=training_cluster,
                             training_data = train_ds,
                             #validation_data = test_ds,
                             label_column_name='valeur_fonciere',
                             **automl_settings
                             )

print("Ready for Auto ML run.")
# Out:
# Ready for Auto ML run.

# %% [markdown]
# ## Run an automated machine learning experiment
#
# OK, you're ready to go. Let's run the automated machine learning experiment.
#
# > **Note**: This may take some time!

# %%
from azureml.core.experiment import Experiment
from azureml.widgets import RunDetails

print('Submitting Auto ML experiment...')
automl_experiment = Experiment(ws, 'mslearn-house-automl-sdk')
automl_run = automl_experiment.submit(automl_config)
RunDetails(automl_run).show()
automl_run.wait_for_completion(show_output=True)
# Out:
# Submitting Auto ML experiment...
# Submitting remote run.
# <table style="width:100%"><tr><th>Experiment</th><th>Id</th><th>Type</th><th>Status</th><th>Details Page</th><th>Docs Page</th></tr><tr><td>mslearn-house-automl-sdk</td><td>AutoML_486098d7-6654-4e8c-adc5-5ac91ae7fa18</td><td>automl</td><td>NotStarted</td><td><a href="https://ml.azure.com/runs/AutoML_486098d7-6654-4e8c-adc5-5ac91ae7fa18?wsid=/subscriptions/d820a79a-27a2-4720-aaad-33b53f92fa93/resourcegroups/teamrocket/workspaces/machinelearningfinal&amp;tid=413600cf-bd4e-4c7c-8a61-69e73cddf731" target="_blank" rel="noopener">Link to Azure Machine Learning studio</a></td><td><a href="https://docs.microsoft.com/en-us/python/api/overview/azure/ml/intro?view=azure-ml-py" target="_blank" rel="noopener">Link to Documentation</a></td></tr></table>
# _AutoMLWidget(widget_settings={'childWidgetDisplay': 'popup', 'send_telemetry': False, 'log_level': 'INFO', 's…
# <table style="width:100%"><tr><th>Experiment</th><th>Id</th><th>Type</th><th>Status</th><th>Details Page</th><th>Docs Page</th></tr><tr><td>mslearn-house-automl-sdk</td><td>AutoML_486098d7-6654-4e8c-adc5-5ac91ae7fa18</td><td>automl</td><td>NotStarted</td><td><a href="https://ml.azure.com/runs/AutoML_486098d7-6654-4e8c-adc5-5ac91ae7fa18?wsid=/subscriptions/d820a79a-27a2-4720-aaad-33b53f92fa93/resourcegroups/teamrocket/workspaces/machinelearningfinal&amp;tid=413600cf-bd4e-4c7c-8a61-69e73cddf731" target="_blank" rel="noopener">Link to Azure Machine Learning studio</a></td><td><a href="https://docs.microsoft.com/en-us/python/api/overview/azure/ml/intro?view=azure-ml-py" target="_blank" rel="noopener">Link to Documentation</a></td></tr></table>
# Current status: FeaturesGeneration. Generating features for the dataset.
# Current status: DatasetCrossValidationSplit. Generating individually featurized CV splits.
# Current status: ModelSelection. Beginning model selection.
#
# ********************************************************************************************
# DATA GUARDRAILS:
#
# TYPE:         Missing feature values imputation
# STATUS:       PASSED
# DESCRIPTION:  No feature missing values were detected in the training data.
#               Learn more about missing value imputation: https://aka.ms/AutomatedMLFeaturization
#
# ********************************************************************************************
#
# TYPE:         High cardinality feature detection
# STATUS:       PASSED
# DESCRIPTION:  Your inputs were analyzed, and no high cardinality features were detected.
#               Learn more about high cardinality feature handling: https://aka.ms/AutomatedMLFeaturization
#
# ********************************************************************************************
#
# ********************************************************************************************
# ITER: The iteration being evaluated.
# PIPELINE: A summary description of the pipeline being evaluated.
# DURATION: Time taken for the current iteration.
# METRIC: The result of computing score on the fitted pipeline.
# BEST: The best observed score thus far.
# ********************************************************************************************
#
#  ITER   PIPELINE                                       DURATION            METRIC      BEST
#     0   MaxAbsScaler LightGBM                          0:00:16             0.3079    0.3079
#     1   MaxAbsScaler XGBoostRegressor                  0:00:16             0.3801    0.3801
#     2   MaxAbsScaler ElasticNet                        0:00:17             0.1473    0.3801
#     3   StandardScalerWrapper XGBoostRegressor         0:00:16             0.5276    0.5276
#     4   StandardScalerWrapper XGBoostRegressor         0:00:16             0.2776    0.5276
#     5   StandardScalerWrapper ExtremeRandomTrees       0:00:16             0.2136    0.5276
#     6   StandardScalerWrapper RandomForest             0:00:16             0.4469    0.5276
#     7   StandardScalerWrapper DecisionTree             0:00:15             0.4210    0.5276
#     8   StandardScalerWrapper LightGBM                 0:00:16             0.2849    0.5276
#     9   StandardScalerWrapper LightGBM                 0:00:18             0.2891    0.5276
#    10   StandardScalerWrapper ElasticNet               0:00:16             0.1475    0.5276
#    11   StandardScalerWrapper ElasticNet               0:00:17             0.1475    0.5276
#    12   MaxAbsScaler ExtremeRandomTrees                0:00:30             0.4695    0.5276
#    13   StandardScalerWrapper XGBoostRegressor         0:00:16             0.5074    0.5276
#    14   StandardScalerWrapper DecisionTree             0:00:16             0.4161    0.5276
#    15   StandardScalerWrapper ElasticNet               0:00:16             0.1474    0.5276
#    16   StandardScalerWrapper ExtremeRandomTrees       0:00:16             0.4065    0.5276
#    17   MaxAbsScaler DecisionTree                      0:00:16             0.4883    0.5276
#    18   MaxAbsScaler SGD                               0:00:15             0.1115    0.5276
#    19   SparseNormalizer XGBoostRegressor              0:00:18             0.4954    0.5276
#    20   MaxAbsScaler RandomForest                      0:00:04             0.4585    0.5276
#    21   StandardScalerWrapper ExtremeRandomTrees       0:00:04             0.4467    0.5276
#    22   SparseNormalizer GradientBoosting              0:00:04             0.5097    0.5276
#    23   StandardScalerWrapper XGBoostRegressor         0:00:04             0.4921    0.5276
#    24   SparseNormalizer RandomForest                  0:00:04             0.4782    0.5276
#    25   TruncatedSVDWrapper XGBoostRegressor           0:00:04            -1.0000    0.5276
#    26   StandardScalerWrapper GradientBoosting         0:00:04             0.4369    0.5276
#    27   StandardScalerWrapper DecisionTree             0:00:04             0.4109    0.5276
#    28   SparseNormalizer XGBoostRegressor              0:00:04             0.3711    0.5276
#    29   SparseNormalizer RandomForest                  0:00:04             0.4331    0.5276
#    30    VotingEnsemble                                0:00:04             0.5453    0.5453
#    31    StackEnsemble                                 0:00:04             0.5410    0.5453
# {'runId': 'AutoML_486098d7-6654-4e8c-adc5-5ac91ae7fa18',
#  'target': 'your-compute-cluster',
#  'status': 'Completed',
#  'startTimeUtc': '2022-03-09T11:34:19.051388Z',
#  'endTimeUtc': '2022-03-09T12:01:31.204379Z',
#  'services': {},
#  'warnings': [{'source': 'JasmineService',
#    'message': 'Experiment timeout reached, hence experiment stopped. Current experiment timeout: 0 hour(s) 18 minute(s)'}],
#  'properties': {'num_iterations': '1000',
#   'training_type': 'TrainFull',
#   'acquisition_function': 'EI',
#   'primary_metric': 'spearman_correlation',
#   'train_split': '0',
#   'acquisition_parameter': '0',
#   'num_cross_validation': '5',
#   'target': 'your-compute-cluster',
#   'AMLSettingsJsonString': '{"path":null,"name":"Automated ML Experiment","subscription_id":"d820a79a-27a2-4720-aaad-33b53f92fa93","resource_group":"teamrocket","workspace_name":"machinelearningfinal","region":"eastus","compute_target":"your-compute-cluster","spark_service":null,"azure_service":"remote","many_models":false,"pipeline_fetch_max_batch_size":1,"enable_batch_run":true,"enable_run_restructure":false,"start_auxiliary_runs_before_parent_complete":false,"enable_code_generation":false,"iterations":1000,"primary_metric":"spearman_correlation","task_type":"regression","positive_label":null,"data_script":null,"test_size":0.0,"test_include_predictions_only":false,"validation_size":0.0,"n_cross_validations":5,"y_min":null,"y_max":null,"num_classes":null,"featurization":"auto","_ignore_package_version_incompatibilities":false,"is_timeseries":false,"max_cores_per_iteration":1,"max_concurrent_iterations":1,"iteration_timeout_minutes":10,"mem_in_mb":null,"enforce_time_on_windows":false,"experiment_timeout_minutes":18,"experiment_exit_score":null,"whitelist_models":null,"blacklist_algos":["TensorFlowDNN","TensorFlowLinearRegressor"],"supported_models":["LassoLars","ExtremeRandomTrees","XGBoostRegressor","OnlineGradientDescentRegressor","ElasticNet","RandomForest","TensorFlowDNN","DecisionTree","GradientBoosting","FastLinearRegressor","KNN","TensorFlowLinearRegressor","TabnetRegressor","SGD","LightGBM"],"private_models":[],"auto_blacklist":true,"blacklist_samples_reached":false,"exclude_nan_labels":true,"verbosity":20,"_debug_log":"azureml_automl.log","show_warnings":false,"model_explainability":true,"service_url":null,"sdk_url":null,"sdk_packages":null,"enable_onnx_compatible_models":false,"enable_split_onnx_featurizer_estimator_models":false,"vm_type":"STANDARD_DS11_V2","telemetry_verbosity":20,"send_telemetry":true,"enable_dnn":false,"scenario":"SDK-1.13.0","environment_label":null,"save_mlflow":false,"enable_categorical_indicators":false,"force_text_dnn":false,"enable_feature_sweeping":true,"enable_early_stopping":true,"early_stopping_n_iters":10,"arguments":null,"dataset_id":null,"hyperdrive_config":null,"validation_dataset_id":null,"run_source":null,"metrics":null,"enable_metric_confidence":false,"enable_ensembling":true,"enable_stack_ensembling":true,"ensemble_iterations":15,"enable_tf":false,"enable_subsampling":null,"subsample_seed":null,"enable_nimbusml":false,"enable_streaming":false,"force_streaming":false,"track_child_runs":true,"allowed_private_models":[],"label_column_name":"valeur_fonciere","weight_column_name":null,"cv_split_column_names":null,"enable_local_managed":false,"_local_managed_run_id":null,"cost_mode":1,"lag_length":0,"metric_operation":"maximize","preprocess":true}',
#   'DataPrepJsonString': '{\\"training_data\\": {\\"datasetId\\": \\"fec70ad2-a048-48ba-920f-d4d264ba3d18\\"}, \\"datasets\\": 0}',
#   'EnableSubsampling': None,
#   'runTemplate': 'AutoML',
#   'azureml.runsource': 'automl',
#   'display_task_type': 'regression',
#   'dependencies_versions': '{"azureml-widgets": "1.38.0", "azureml-train": "1.38.0", "azureml-train-restclients-hyperdrive": "1.38.0", "azureml-train-core": "1.38.0", "azureml-train-automl": "1.38.0", "azureml-train-automl-runtime": "1.38.0", "azureml-train-automl-client": "1.38.0", "azureml-tensorboard": "1.38.0", "azureml-telemetry": "1.38.0", "azureml-sdk": "1.38.0", "azureml-responsibleai": "1.38.0", "azureml-pipeline": "1.38.0", "azureml-pipeline-steps": "1.38.0", "azureml-pipeline-core": "1.38.0", "azureml-opendatasets": "1.38.0", "azureml-mlflow": "1.38.0", "azureml-interpret": "1.38.0", "azureml-inference-server-http": "0.4.2", "azureml-explain-model": "1.38.0", "azureml-defaults": "1.38.0", "azureml-dataset-runtime": "1.38.0", "azureml-dataprep": "2.26.0", "azureml-dataprep-rslex": "2.2.0", "azureml-dataprep-native": "38.0.0", "azureml-datadrift": "1.38.0", "azureml-core": "1.38.0", "azureml-contrib-services": "1.38.0", "azureml-contrib-server": "1.38.0", "azureml-contrib-reinforcementlearning": "1.38.0", "azureml-contrib-pipeline-steps": "1.38.0", "azureml-contrib-notebook": "1.38.0", "azureml-contrib-fairness": "1.38.0", "azureml-contrib-dataset": "1.38.0", "azureml-contrib-automl-pipeline-steps": "1.38.0", "azureml-cli-common": "1.38.0", "azureml-automl-runtime": "1.38.0", "azureml-automl-dnn-nlp": "1.38.0", "azureml-automl-core": "1.38.0", "azureml-accel-models": "1.38.0"}',
#   '_aml_system_scenario_identification': 'Remote.Parent',
#   'ClientType': 'SDK',
#   'environment_cpu_name': 'AzureML-AutoML',
#   'environment_cpu_label': 'py36',
#   'environment_gpu_name': 'AzureML-AutoML-GPU',
#   'environment_gpu_label': 'py36',
#   'root_attribution': 'automl',
#   'attribution': 'AutoML',
#   'Orchestrator': 'AutoML',
#   'CancelUri': 'https://eastus.api.azureml.ms/jasmine/v1.0/subscriptions/d820a79a-27a2-4720-aaad-33b53f92fa93/resourceGroups/teamrocket/providers/Microsoft.MachineLearningServices/workspaces/machinelearningfinal/experimentids/50e76b74-c506-4d3f-9d3e-e1f128f228d7/cancel/AutoML_486098d7-6654-4e8c-adc5-5ac91ae7fa18',
#   'azureml.git.repository_uri': 'https://github.com/MicrosoftLearning/mslearn-dp100',
#   'mlflow.source.git.repoURL': 'https://github.com/MicrosoftLearning/mslearn-dp100',
#   'azureml.git.branch': 'main',
#   'mlflow.source.git.branch': 'main',
#   'azureml.git.commit': '0df707684204dd059eb4fb1cc942bfe90013bbfd',
#   'mlflow.source.git.commit': '0df707684204dd059eb4fb1cc942bfe90013bbfd',
#   'azureml.git.dirty': 'True',
#   'ClientSdkVersion': '1.38.0',
#   'snapshotId': '00000000-0000-0000-0000-000000000000',
#   'SetupRunId': 'AutoML_486098d7-6654-4e8c-adc5-5ac91ae7fa18_setup',
#   'SetupRunContainerId': 'dcid.AutoML_486098d7-6654-4e8c-adc5-5ac91ae7fa18_setup',
#   'FeaturizationRunJsonPath': 'featurizer_container.json',
#   'FeaturizationRunId': 'AutoML_486098d7-6654-4e8c-adc5-5ac91ae7fa18_featurize',
#   'ProblemInfoJsonString': '{"dataset_num_categorical": 0, "is_sparse": true, "subsampling": false, "has_extra_col": true, "dataset_classes": 674, "dataset_features": 51, "dataset_samples": 1357, "single_frequency_class_detected": false}',
#   'ModelExplainRunId': 'AutoML_486098d7-6654-4e8c-adc5-5ac91ae7fa18_ModelExplain'},
#  'inputDatasets': [{'dataset': {'id': 'fec70ad2-a048-48ba-920f-d4d264ba3d18'}, 'consumptionDetails': {'type': 'RunInput', 'inputName': 'training_data', 'mechanism': 'Direct'}}],
#  'outputDatasets': [],
#  'logFiles': {},
#  'submittedBy': 'Julie NGAN'}
# WARNING:urllib3.connectionpool:Retrying (Retry(total=2, connect=2, read=3, redirect=None, status=None)) after connection broken by 'NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7f898f7a5240>: Failed to establish a new connection: [Errno 111] Connection refused',)': /history/v1.0/subscriptions/d820a79a-27a2-4720-aaad-33b53f92fa93/resourceGroups/teamrocket/providers/Microsoft.MachineLearningServices/workspaces/machinelearningfinal/experiments/mslearn-house-automl-sdk/metrics:query?mergestrategytype=None

# %% [markdown]
# ## View child run details
#
# When the experiment has completed, view the output in the widget, and click the run that produced the best result to see its details.
#
# Then click the link to view the experiment details in Azure Machine Learning studio and view the overall experiment details before viewing the details for the individual run that produced the best result. There's lots of information here about the performance of the model generated.
#
# You can also retrieve all of the child runs and view their metrics using the SDK:

# %%
for run in automl_run.get_children():
    print('Run ID', run.id)
    for metric in run.get_metrics():
        print('\t', run.get_metrics(metric))
# Out:
# Run ID AutoML_486098d7-6654-4e8c-adc5-5ac91ae7fa18_31
# 	 {'root_mean_squared_log_error': 1.12388423078108}
# 	 {'normalized_median_absolute_error': 0.008232198415443367}
# 	 {'normalized_root_mean_squared_error': 0.07744652397708732}
# 	 {'spearman_correlation': 0.5410396127665769}
# 	 {'median_absolute_error': 260425.5869939128}
# 	 {'r2_score': 0.2523911365094448}
# 	 {'mean_absolute_percentage_error': 98448.79681620092}
# 	 {'normalized_mean_absolute_error': 0.025781291629438124}
# 	 {'normalized_root_mean_squared_log_error': 0.06819140777126785}
# 	 {'root_mean_squared_error': 2450020.6930793286}
# 	 {'explained_variance': 0.2592131488530528}
# 	 {'mean_absolute_error': 815591.1297597252}
# 	 {'residuals': 'aml://artifactId/ExperimentRun/dcid.AutoML_486098d7-6654-4e8c-adc5-5ac91ae7fa18_31/residuals'}
# 	 {'predicted_true': 'aml://artifactId/ExperimentRun/dcid.AutoML_486098d7-6654-4e8c-adc5-5ac91ae7fa18_31/predicted_true'}
# Run ID AutoML_486098d7-6654-4e8c-adc5-5ac91ae7fa18_30
# 	 {'r2_score': 0.2854655467465753}
# 	 {'root_mean_squared_log_error': 1.0074004589163956}
# 	 {'normalized_median_absolute_error': 0.004078531758350637}
# 	 {'mean_absolute_error': 732218.3787327859}
# 	 {'spearman_correlation': 0.5453013597820174}
# 	 {'explained_variance': 0.2883179643232707}
# 	 {'normalized_mean_absolute_error': 0.02314583235365212}
# 	 {'normalized_root_mean_squared_error': 0.07553715390332427}
# 	 {'root_mean_squared_error': 2389617.7730870782}
# 	 {'normalized_root_mean_squared_log_error': 0.061123782682837136}
# 	 {'median_absolute_error': 129024.34728118428}
# 	 {'mean_absolute_percentage_error': 97379.71853308132}
# 	 {'predicted_true': 'aml://artifactId/ExperimentRun/dcid.AutoML_486098d7-6654-4e8c-adc5-5ac91ae7fa18_30/predicted_true'}
# 	 {'residuals': 'aml://artifactId/ExperimentRun/dcid.AutoML_486098d7-6654-4e8c-adc5-5ac91ae7fa18_30/residuals'}
# Run ID AutoML_486098d7-6654-4e8c-adc5-5ac91ae7fa18_29
# 	 {'mean_absolute_error': 904291.4564591363}
# 	 {'spearman_correlation': 0.43313654551514136}
# 	 {'normalized_root_mean_squared_error': 0.08068779451044336}
# 	 {'median_absolute_error': 185216.89056291812}
# 	 {'mean_absolute_percentage_error': 130130.95389212803}
# 	 {'normalized_root_mean_squared_log_error': 0.07154064101019617}
# 	 {'normalized_mean_absolute_error': 0.028585158551013956}
# 	 {'root_mean_squared_log_error': 1.1790840066101014}
# 	 {'explained_variance': 0.24142243499547744}
# 	 {'r2_score': 0.23547417314977145}
# 	 {'root_mean_squared_error': 2552558.2825125223}
# 	 {'normalized_median_absolute_error': 0.005854809470165624}
# 	 {'predicted_true': 'aml://artifactId/ExperimentRun/dcid.AutoML_486098d7-6654-4e8c-adc5-5ac91ae7fa18_29/predicted_true'}
# 	 {'residuals': 'aml://artifactId/ExperimentRun/dcid.AutoML_486098d7-6654-4e8c-adc5-5ac91ae7fa18_29/residuals'}
# Run ID AutoML_486098d7-6654-4e8c-adc5-5ac91ae7fa18_28
# 	 {'r2_score': -0.043425356751381504}
# 	 {'mean_absolute_error': 902801.7138884909}
# 	 {'normalized_root_mean_squared_log_error': nan}
# 	 {'normalized_root_mean_squared_error': 0.08910988152373416}
# 	 {'root_mean_squared_error': 2818990.9950714717}
# 	 {'mean_absolute_percentage_error': 107503.51888783628}
# 	 {'root_mean_squared_log_error': nan}
# 	 {'median_absolute_error': 175358.325}
# 	 {'normalized_median_absolute_error': 0.005543174700547167}
# 	 {'explained_variance': -0.0335939022128835}
# 	 {'normalized_mean_absolute_error': 0.028538066955402917}
# 	 {'spearman_correlation': 0.3711040101984297}
# 	 {'predicted_true': 'aml://artifactId/ExperimentRun/dcid.AutoML_486098d7-6654-4e8c-adc5-5ac91ae7fa18_28/predicted_true'}
# 	 {'residuals': 'aml://artifactId/ExperimentRun/dcid.AutoML_486098d7-6654-4e8c-adc5-5ac91ae7fa18_28/residuals'}
# Run ID AutoML_486098d7-6654-4e8c-adc5-5ac91ae7fa18_27
# 	 {'spearman_correlation': 0.41086385773158335}
# 	 {'normalized_mean_absolute_error': 0.032442165291618086}
# 	 {'normalized_root_mean_squared_error': 0.08804961190197272}
# 	 {'r2_score': 0.08628841953587385}
# 	 {'root_mean_squared_log_error': 1.2440547894911238}
# 	 {'mean_absolute_error': 1026307.8600697396}
# 	 {'normalized_root_mean_squared_log_error': 0.07548272777261941}
# 	 {'root_mean_squared_error': 2785449.366859373}
# 	 {'normalized_median_absolute_error': 0.006356189229619005}
# 	 {'explained_variance': 0.09480331973507532}
# 	 {'median_absolute_error': 201078.03865157015}
# 	 {'mean_absolute_percentage_error': 77571.5731483225}
# 	 {'residuals': 'aml://artifactId/ExperimentRun/dcid.AutoML_486098d7-6654-4e8c-adc5-5ac91ae7fa18_27/residuals'}
# 	 {'predicted_true': 'aml://artifactId/ExperimentRun/dcid.AutoML_486098d7-6654-4e8c-adc5-5ac91ae7fa18_27/predicted_true'}
# Run ID AutoML_486098d7-6654-4e8c-adc5-5ac91ae7fa18_26
# 	 {'r2_score': 0.10535571733385585}
# 	 {'root_mean_squared_error': 2810381.959970834}
# 	 {'root_mean_squared_log_error': 1.0096270464793773}
# 	 {'explained_variance': 0.13003499584742068}
# 	 {'mean_absolute_percentage_error': 91192.7699714645}
# 	 {'normalized_median_absolute_error': 0.004280413390905144}
# 	 {'normalized_root_mean_squared_error': 0.08883774511067262}
# 	 {'normalized_root_mean_squared_log_error': 0.06125888035240778}
# 	 {'spearman_correlation': 0.4368696065559943}
# 	 {'median_absolute_error': 135410.87248478815}
# 	 {'normalized_mean_absolute_error': 0.0247959421965304}
# 	 {'mean_absolute_error': 784419.6016321087}
# 	 {'residuals': 'aml://artifactId/ExperimentRun/dcid.AutoML_486098d7-6654-4e8c-adc5-5ac91ae7fa18_26/residuals'}
# 	 {'predicted_true': 'aml://artifactId/ExperimentRun/dcid.AutoML_486098d7-6654-4e8c-adc5-5ac91ae7fa18_26/predicted_true'}
# Run ID AutoML_486098d7-6654-4e8c-adc5-5ac91ae7fa18_25
# 	 {'spearman_correlation': -1.0}
# 	 {'root_mean_squared_error': 2971767.281506983}
# 	 {'mean_absolute_error': 1210653.7081269403}
# 	 {'r2_score': -0.01742283888494196}
# 	 {'mean_absolute_percentage_error': 70224.31416675884}
# 	 {'median_absolute_error': 726999.6625}
# 	 {'normalized_root_mean_squared_error': 0.09393922535906601}
# 	 {'normalized_median_absolute_error': 0.022980865815616848}
# 	 {'normalized_mean_absolute_error': 0.038269440621155955}
# 	 {'explained_variance': -4.4408920985006264e-17}
# 	 {'root_mean_squared_log_error': 1.499916340630289}
# 	 {'normalized_root_mean_squared_log_error': 0.09100706639119238}
# 	 {'residuals': 'aml://artifactId/ExperimentRun/dcid.AutoML_486098d7-6654-4e8c-adc5-5ac91ae7fa18_25/residuals'}
# 	 {'predicted_true': 'aml://artifactId/ExperimentRun/dcid.AutoML_486098d7-6654-4e8c-adc5-5ac91ae7fa18_25/predicted_true'}
# Run ID AutoML_486098d7-6654-4e8c-adc5-5ac91ae7fa18_24
# 	 {'r2_score': 0.3051014931444637}
# 	 {'spearman_correlation': 0.47819154894014526}
# 	 {'mean_absolute_percentage_error': 171085.8000511292}
# 	 {'normalized_root_mean_squared_error': 0.07736250375898171}
# 	 {'normalized_root_mean_squared_log_error': 0.06823996330145647}
# 	 {'normalized_median_absolute_error': 0.005815414535891746}
# 	 {'mean_absolute_error': 818369.3211531796}
# 	 {'normalized_mean_absolute_error': 0.025869111812742658}
# 	 {'median_absolute_error': 183970.63186443798}
# 	 {'root_mean_squared_error': 2447362.7135803816}
# 	 {'explained_variance': 0.3101439753924649}
# 	 {'root_mean_squared_log_error': 1.1246844898823327}
# 	 {'residuals': 'aml://artifactId/ExperimentRun/dcid.AutoML_486098d7-6654-4e8c-adc5-5ac91ae7fa18_24/residuals'}
# 	 {'predicted_true': 'aml://artifactId/ExperimentRun/dcid.AutoML_486098d7-6654-4e8c-adc5-5ac91ae7fa18_24/predicted_true'}
# Run ID AutoML_486098d7-6654-4e8c-adc5-5ac91ae7fa18_23
# 	 {'mean_absolute_percentage_error': 84967.89473580873}
# 	 {'normalized_mean_absolute_error': 0.022942676117681325}
# 	 {'normalized_median_absolute_error': 0.004268280349990087}
# 	 {'normalized_root_mean_squared_log_error': 0.059579628109418595}
# 	 {'root_mean_squared_log_error': 0.9819507573825199}
# 	 {'median_absolute_error': 135027.04375}
# 	 {'explained_variance': 0.20200007876344578}
# 	 {'r2_score': 0.19770052608630848}
# 	 {'mean_absolute_error': 725791.5314516375}
# 	 {'root_mean_squared_error': 2449606.9986997745}
# 	 {'spearman_correlation': 0.4921321783283471}
# 	 {'normalized_root_mean_squared_error': 0.07743344686644257}
# 	 {'residuals': 'aml://artifactId/ExperimentRun/dcid.AutoML_486098d7-6654-4e8c-adc5-5ac91ae7fa18_23/residuals'}
# 	 {'predicted_true': 'aml://artifactId/ExperimentRun/dcid.AutoML_486098d7-6654-4e8c-adc5-5ac91ae7fa18_23/predicted_true'}
# Run ID AutoML_486098d7-6654-4e8c-adc5-5ac91ae7fa18_22
# 	 {'r2_score': 0.11424221468730363}
# 	 {'median_absolute_error': 134323.4644045134}
# 	 {'normalized_median_absolute_error': 0.004246039813490158}
# 	 {'normalized_mean_absolute_error': 0.02372759154140884}
# 	 {'mean_absolute_error': 750622.3299393589}
# 	 {'root_mean_squared_log_error': 1.0051476678207119}
# 	 {'mean_absolute_percentage_error': 104948.53964046252}
# 	 {'normalized_root_mean_squared_log_error': 0.06098709512016666}
# 	 {'explained_variance': 0.13582452604927203}
# 	 {'normalized_root_mean_squared_error': 0.088448186760719}
# 	 {'spearman_correlation': 0.5096757518630664}
# 	 {'root_mean_squared_error': 2798058.2820375217}
# 	 {'predicted_true': 'aml://artifactId/ExperimentRun/dcid.AutoML_486098d7-6654-4e8c-adc5-5ac91ae7fa18_22/predicted_true'}
# 	 {'residuals': 'aml://artifactId/ExperimentRun/dcid.AutoML_486098d7-6654-4e8c-adc5-5ac91ae7fa18_22/residuals'}
# Run ID AutoML_486098d7-6654-4e8c-adc5-5ac91ae7fa18_21
# 	 {'normalized_median_absolute_error': 0.006345720920217984}
# 	 {'mean_absolute_error': 858305.8365308922}
# 	 {'mean_absolute_percentage_error': 148636.13132313447}
# 	 {'median_absolute_error': 200746.87369623082}
# 	 {'explained_variance': 0.2143493510870579}
# 	 {'root_mean_squared_error': 2477737.9043369642}
# 	 {'normalized_root_mean_squared_error': 0.07832268052233857}
# 	 {'spearman_correlation': 0.4467426246649904}
# 	 {'r2_score': 0.2103565691562391}
# 	 {'root_mean_squared_log_error': 1.1248305459058772}
# 	 {'normalized_root_mean_squared_log_error': 0.06824882521586562}
# 	 {'normalized_mean_absolute_error': 0.02713152739335309}
# 	 {'residuals': 'aml://artifactId/ExperimentRun/dcid.AutoML_486098d7-6654-4e8c-adc5-5ac91ae7fa18_21/residuals'}
# 	 {'predicted_true': 'aml://artifactId/ExperimentRun/dcid.AutoML_486098d7-6654-4e8c-adc5-5ac91ae7fa18_21/predicted_true'}
# Run ID AutoML_486098d7-6654-4e8c-adc5-5ac91ae7fa18_20
# 	 {'mean_absolute_percentage_error': 94520.28166375769}
# 	 {'normalized_root_mean_squared_log_error': 0.07073509895226222}
# 	 {'normalized_median_absolute_error': 0.005274528829503834}
# 	 {'r2_score': 0.22473627156066858}
# 	 {'mean_absolute_error': 888895.7604209248}
# 	 {'root_mean_squared_error': 2551814.702070971}
# 	 {'normalized_root_mean_squared_error': 0.08066428951693119}
# 	 {'spearman_correlation': 0.45854742729505826}
# 	 {'explained_variance': 0.2305098777939719}
# 	 {'median_absolute_error': 166859.7131919192}
# 	 {'root_mean_squared_log_error': 1.1658076123291732}
# 	 {'normalized_mean_absolute_error': 0.02809849199112107}
# 	 {'predicted_true': 'aml://artifactId/ExperimentRun/dcid.AutoML_486098d7-6654-4e8c-adc5-5ac91ae7fa18_20/predicted_true'}
# 	 {'residuals': 'aml://artifactId/ExperimentRun/dcid.AutoML_486098d7-6654-4e8c-adc5-5ac91ae7fa18_20/residuals'}
# Run ID AutoML_486098d7-6654-4e8c-adc5-5ac91ae7fa18_19
# 	 {'normalized_mean_absolute_error': 0.024056110107658908}
# 	 {'r2_score': 0.06812751428589733}
# 	 {'mean_absolute_percentage_error': 179685.82512102087}
# 	 {'median_absolute_error': 135619.4359375}
# 	 {'normalized_median_absolute_error': 0.004287006198258493}
# 	 {'explained_variance': 0.07686156101116541}
# 	 {'mean_absolute_error': 761015.0143884574}
# 	 {'spearman_correlation': 0.4954443642011855}
# 	 {'root_mean_squared_error': 2636171.262113907}
# 	 {'normalized_root_mean_squared_log_error': 0.06338812853487626}
# 	 {'root_mean_squared_log_error': 1.0447198614528186}
# 	 {'normalized_root_mean_squared_error': 0.08333084754578549}
# 	 {'residuals': 'aml://artifactId/ExperimentRun/dcid.AutoML_486098d7-6654-4e8c-adc5-5ac91ae7fa18_19/residuals'}
# 	 {'predicted_true': 'aml://artifactId/ExperimentRun/dcid.AutoML_486098d7-6654-4e8c-adc5-5ac91ae7fa18_19/predicted_true'}
# Run ID AutoML_486098d7-6654-4e8c-adc5-5ac91ae7fa18_18
# 	 {'normalized_mean_absolute_error': 0.04077528600108458}
# 	 {'r2_score': 0.03865421476857456}
# 	 {'mean_absolute_percentage_error': 134581.22467936535}
# 	 {'median_absolute_error': 673375.6755762945}
# 	 {'normalized_median_absolute_error': 0.021285781606424293}
# 	 {'explained_variance': 0.04711758959037262}
# 	 {'mean_absolute_error': 1289926.1237139672}
# 	 {'spearman_correlation': 0.11151442309520174}
# 	 {'root_mean_squared_error': 2835823.089769154}
# 	 {'normalized_root_mean_squared_log_error': nan}
# 	 {'root_mean_squared_log_error': nan}
# 	 {'normalized_root_mean_squared_error': 0.08964195344837989}
# 	 {'residuals': 'aml://artifactId/ExperimentRun/dcid.AutoML_486098d7-6654-4e8c-adc5-5ac91ae7fa18_18/residuals'}
# 	 {'predicted_true': 'aml://artifactId/ExperimentRun/dcid.AutoML_486098d7-6654-4e8c-adc5-5ac91ae7fa18_18/predicted_true'}
# Run ID AutoML_486098d7-6654-4e8c-adc5-5ac91ae7fa18_17
# 	 {'normalized_mean_absolute_error': 0.02587068619725147}
# 	 {'r2_score': 0.05944983947590841}
# 	 {'mean_absolute_percentage_error': 45845.551675781564}
# 	 {'median_absolute_error': 130626.25}
# 	 {'normalized_median_absolute_error': 0.004129168798956933}
# 	 {'explained_variance': 0.06279595490609516}
# 	 {'mean_absolute_error': 818419.1268052267}
# 	 {'spearman_correlation': 0.4883379052059693}
# 	 {'root_mean_squared_error': 2725392.4096695897}
# 	 {'normalized_root_mean_squared_log_error': 0.0639774399999502}
# 	 {'root_mean_squared_log_error': 1.0544324907159761}
# 	 {'normalized_root_mean_squared_error': 0.08615117790583225}
# 	 {'residuals': 'aml://artifactId/ExperimentRun/dcid.AutoML_486098d7-6654-4e8c-adc5-5ac91ae7fa18_17/residuals'}
# 	 {'predicted_true': 'aml://artifactId/ExperimentRun/dcid.AutoML_486098d7-6654-4e8c-adc5-5ac91ae7fa18_17/predicted_true'}
# Run ID AutoML_486098d7-6654-4e8c-adc5-5ac91ae7fa18_16
# 	 {'normalized_mean_absolute_error': 0.02953579505311386}
# 	 {'r2_score': 0.19277451361853537}
# 	 {'mean_absolute_percentage_error': 139710.18041223355}
# 	 {'median_absolute_error': 227708.53561337665}
# 	 {'normalized_median_absolute_error': 0.007197994128369514}
# 	 {'explained_variance': 0.1985820587003768}
# 	 {'mean_absolute_error': 934364.8410623029}
# 	 {'spearman_correlation': 0.40645005149273283}
# 	 {'root_mean_squared_error': 2548180.831498401}
# 	 {'normalized_root_mean_squared_log_error': 0.07262637277215632}
# 	 {'root_mean_squared_log_error': 1.1969782963161912}
# 	 {'normalized_root_mean_squared_error': 0.08054942083634284}
# 	 {'residuals': 'aml://artifactId/ExperimentRun/dcid.AutoML_486098d7-6654-4e8c-adc5-5ac91ae7fa18_16/residuals'}
# 	 {'predicted_true': 'aml://artifactId/ExperimentRun/dcid.AutoML_486098d7-6654-4e8c-adc5-5ac91ae7fa18_16/predicted_true'}
# Run ID AutoML_486098d7-6654-4e8c-adc5-5ac91ae7fa18_15
# 	 {'normalized_mean_absolute_error': 0.03941886084359551}
# 	 {'r2_score': 0.03360964074856203}
# 	 {'mean_absolute_percentage_error': 139146.3724702149}
# 	 {'median_absolute_error': 616993.6932792843}
# 	 {'normalized_median_absolute_error': 0.019503515621416247}
# 	 {'explained_variance': 0.04525192874053261}
# 	 {'mean_absolute_error': 1247015.615484511}
# 	 {'spearman_correlation': 0.14740472229167087}
# 	 {'root_mean_squared_error': 2825855.156474485}
# 	 {'normalized_root_mean_squared_log_error': nan}
# 	 {'root_mean_squared_log_error': nan}
# 	 {'normalized_root_mean_squared_error': 0.08932686150361051}
# 	 {'residuals': 'aml://artifactId/ExperimentRun/dcid.AutoML_486098d7-6654-4e8c-adc5-5ac91ae7fa18_15/residuals'}
# 	 {'predicted_true': 'aml://artifactId/ExperimentRun/dcid.AutoML_486098d7-6654-4e8c-adc5-5ac91ae7fa18_15/predicted_true'}
# Run ID AutoML_486098d7-6654-4e8c-adc5-5ac91ae7fa18_14
# 	 {'normalized_mean_absolute_error': 0.02937360600779453}
# 	 {'r2_score': 0.029625078463402742}
# 	 {'mean_absolute_percentage_error': 95440.601089222}
# 	 {'median_absolute_error': 150368.0081221421}
# 	 {'normalized_median_absolute_error': 0.004753216811316652}
# 	 {'explained_variance': 0.03195006912038152}
# 	 {'mean_absolute_error': 929233.9908082526}
# 	 {'spearman_correlation': 0.4160859707065848}
# 	 {'root_mean_squared_error': 2802799.384393892}
# 	 {'normalized_root_mean_squared_log_error': 0.07170407778944123}
# 	 {'root_mean_squared_log_error': 1.181777660032528}
# 	 {'normalized_root_mean_squared_error': 0.08859805565707472}
# 	 {'residuals': 'aml://artifactId/ExperimentRun/dcid.AutoML_486098d7-6654-4e8c-adc5-5ac91ae7fa18_14/residuals'}
# 	 {'predicted_true': 'aml://artifactId/ExperimentRun/dcid.AutoML_486098d7-6654-4e8c-adc5-5ac91ae7fa18_14/predicted_true'}
# Run ID AutoML_486098d7-6654-4e8c-adc5-5ac91ae7fa18_13
# 	 {'normalized_mean_absolute_error': 0.023536479755285625}
# 	 {'r2_score': 0.10925415719614047}
# 	 {'mean_absolute_percentage_error': 107640.18516414714}
# 	 {'median_absolute_error': 129572.234375}
# 	 {'normalized_median_absolute_error': 0.004095850775723752}
# 	 {'explained_variance': 0.11755352978861344}
# 	 {'mean_absolute_error': 744576.508814685}
# 	 {'spearman_correlation': 0.5073910106733728}
# 	 {'root_mean_squared_error': 2543889.4844291685}
# 	 {'normalized_root_mean_squared_log_error': 0.06022110336317081}
# 	 {'root_mean_squared_log_error': 0.9925231146001131}
# 	 {'normalized_root_mean_squared_error': 0.08041376895608318}
# 	 {'residuals': 'aml://artifactId/ExperimentRun/dcid.AutoML_486098d7-6654-4e8c-adc5-5ac91ae7fa18_13/residuals'}
# 	 {'predicted_true': 'aml://artifactId/ExperimentRun/dcid.AutoML_486098d7-6654-4e8c-adc5-5ac91ae7fa18_13/predicted_true'}
# Run ID AutoML_486098d7-6654-4e8c-adc5-5ac91ae7fa18_12
# 	 {'normalized_mean_absolute_error': 0.024622685597090847}
# 	 {'r2_score': 0.017513467840233797}
# 	 {'mean_absolute_percentage_error': 95940.6325963091}
# 	 {'median_absolute_error': 130751.42}
# 	 {'normalized_median_absolute_error': 0.0041331254926426616}
# 	 {'explained_variance': 0.05645683297721989}
# 	 {'mean_absolute_error': 778938.6293167464}
# 	 {'spearman_correlation': 0.4695190414023848}
# 	 {'root_mean_squared_error': 2938296.6758771143}
# 	 {'normalized_root_mean_squared_log_error': 0.06285316285432654}
# 	 {'root_mean_squared_log_error': 1.0359029223100518}
# 	 {'normalized_root_mean_squared_error': 0.09288120080083943}
# 	 {'residuals': 'aml://artifactId/ExperimentRun/dcid.AutoML_486098d7-6654-4e8c-adc5-5ac91ae7fa18_12/residuals'}
# 	 {'predicted_true': 'aml://artifactId/ExperimentRun/dcid.AutoML_486098d7-6654-4e8c-adc5-5ac91ae7fa18_12/predicted_true'}
# Run ID AutoML_486098d7-6654-4e8c-adc5-5ac91ae7fa18_11
# 	 {'normalized_mean_absolute_error': 0.040038663183441826}
# 	 {'r2_score': 0.02289580778112943}
# 	 {'mean_absolute_percentage_error': 144609.41887393675}
# 	 {'median_absolute_error': 633283.7214809626}
# 	 {'normalized_median_absolute_error': 0.020018452521040165}
# 	 {'explained_variance': 0.03435305955065253}
# 	 {'mean_absolute_error': 1266623.0617617865}
# 	 {'spearman_correlation': 0.14751880887445207}
# 	 {'root_mean_squared_error': 2832465.71203031}
# 	 {'normalized_root_mean_squared_log_error': nan}
# 	 {'root_mean_squared_log_error': nan}
# 	 {'normalized_root_mean_squared_error': 0.08953582486085981}
# 	 {'residuals': 'aml://artifactId/ExperimentRun/dcid.AutoML_486098d7-6654-4e8c-adc5-5ac91ae7fa18_11/residuals'}
# 	 {'predicted_true': 'aml://artifactId/ExperimentRun/dcid.AutoML_486098d7-6654-4e8c-adc5-5ac91ae7fa18_11/predicted_true'}
# Run ID AutoML_486098d7-6654-4e8c-adc5-5ac91ae7fa18_10
# 	 {'normalized_mean_absolute_error': 0.039611061905057914}
# 	 {'r2_score': 0.030418644239678393}
# 	 {'mean_absolute_percentage_error': 140253.38425224644}
# 	 {'median_absolute_error': 617415.4318849177}
# 	 {'normalized_median_absolute_error': 0.01951684701454509}
# 	 {'explained_variance': 0.04200879940712319}
# 	 {'mean_absolute_error': 1253095.895833233}
# 	 {'spearman_correlation': 0.14754834239220357}
# 	 {'root_mean_squared_error': 2827835.766498404}
# 	 {'normalized_root_mean_squared_log_error': nan}
# 	 {'root_mean_squared_log_error': nan}
# 	 {'normalized_root_mean_squared_error': 0.08938946969387601}
# 	 {'residuals': 'aml://artifactId/ExperimentRun/dcid.AutoML_486098d7-6654-4e8c-adc5-5ac91ae7fa18_10/residuals'}
# 	 {'predicted_true': 'aml://artifactId/ExperimentRun/dcid.AutoML_486098d7-6654-4e8c-adc5-5ac91ae7fa18_10/predicted_true'}
# Run ID AutoML_486098d7-6654-4e8c-adc5-5ac91ae7fa18_9
# 	 {'normalized_mean_absolute_error': 0.03315703612938493}
# 	 {'r2_score': 0.2956569791317122}
# 	 {'mean_absolute_percentage_error': 42184.526082603974}
# 	 {'median_absolute_error': 451207.45606583264}
# 	 {'normalized_median_absolute_error': 0.014262919967799482}
# 	 {'explained_variance': 0.2999055445810677}
# 	 {'mean_absolute_error': 1048922.798164649}
# 	 {'spearman_correlation': 0.28907479514049333}
# 	 {'root_mean_squared_error': 2283787.174419121}
# 	 {'normalized_root_mean_squared_log_error': nan}
# 	 {'root_mean_squared_log_error': nan}
# 	 {'normalized_root_mean_squared_error': 0.07219178950685215}
# 	 {'residuals': 'aml://artifactId/ExperimentRun/dcid.AutoML_486098d7-6654-4e8c-adc5-5ac91ae7fa18_9/residuals'}
# 	 {'predicted_true': 'aml://artifactId/ExperimentRun/dcid.AutoML_486098d7-6654-4e8c-adc5-5ac91ae7fa18_9/predicted_true'}
# Run ID AutoML_486098d7-6654-4e8c-adc5-5ac91ae7fa18_8
# 	 {'normalized_mean_absolute_error': 0.032368663731145296}
# 	 {'r2_score': 0.20776105329457395}
# 	 {'mean_absolute_percentage_error': 66289.26035892597}
# 	 {'median_absolute_error': 326770.11556181253}
# 	 {'normalized_median_absolute_error': 0.010329386058387098}
# 	 {'explained_variance': 0.21331050842956456}
# 	 {'mean_absolute_error': 1023982.638292385}
# 	 {'spearman_correlation': 0.28492239050622575}
# 	 {'root_mean_squared_error': 2508564.919131751}
# 	 {'normalized_root_mean_squared_log_error': nan}
# 	 {'root_mean_squared_log_error': nan}
# 	 {'normalized_root_mean_squared_error': 0.07929713969616939}
# 	 {'residuals': 'aml://artifactId/ExperimentRun/dcid.AutoML_486098d7-6654-4e8c-adc5-5ac91ae7fa18_8/residuals'}
# 	 {'predicted_true': 'aml://artifactId/ExperimentRun/dcid.AutoML_486098d7-6654-4e8c-adc5-5ac91ae7fa18_8/predicted_true'}
# Run ID AutoML_486098d7-6654-4e8c-adc5-5ac91ae7fa18_7
# 	 {'normalized_mean_absolute_error': 0.029446882737956464}
# 	 {'r2_score': -0.009519904153873516}
# 	 {'mean_absolute_percentage_error': 139846.90945889355}
# 	 {'median_absolute_error': 148429.32719164013}
# 	 {'normalized_median_absolute_error': 0.004691934023137694}
# 	 {'explained_variance': -0.006594345912768929}
# 	 {'mean_absolute_error': 931552.1000789932}
# 	 {'spearman_correlation': 0.4209671913691144}
# 	 {'root_mean_squared_error': 2859995.706402225}
# 	 {'normalized_root_mean_squared_log_error': 0.07138334874223815}
# 	 {'root_mean_squared_log_error': 1.176491622828045}
# 	 {'normalized_root_mean_squared_error': 0.09040606337567572}
# 	 {'residuals': 'aml://artifactId/ExperimentRun/dcid.AutoML_486098d7-6654-4e8c-adc5-5ac91ae7fa18_7/residuals'}
# 	 {'predicted_true': 'aml://artifactId/ExperimentRun/dcid.AutoML_486098d7-6654-4e8c-adc5-5ac91ae7fa18_7/predicted_true'}
# Run ID AutoML_486098d7-6654-4e8c-adc5-5ac91ae7fa18_worker_0
# Run ID AutoML_486098d7-6654-4e8c-adc5-5ac91ae7fa18_6
# 	 {'normalized_mean_absolute_error': 0.029045942129318002}
# 	 {'r2_score': 0.20235982411046766}
# 	 {'mean_absolute_percentage_error': 94971.22525443559}
# 	 {'median_absolute_error': 201195.16834509635}
# 	 {'normalized_median_absolute_error': 0.006359891764721556}
# 	 {'explained_variance': 0.2080541748363986}
# 	 {'mean_absolute_error': 918868.3444058446}
# 	 {'spearman_correlation': 0.44692123420980856}
# 	 {'root_mean_squared_error': 2605114.84979443}
# 	 {'normalized_root_mean_squared_log_error': 0.07288197786368646}
# 	 {'root_mean_squared_log_error': 1.2011910049413257}
# 	 {'normalized_root_mean_squared_error': 0.08234913698793724}
# 	 {'residuals': 'aml://artifactId/ExperimentRun/dcid.AutoML_486098d7-6654-4e8c-adc5-5ac91ae7fa18_6/residuals'}
# 	 {'predicted_true': 'aml://artifactId/ExperimentRun/dcid.AutoML_486098d7-6654-4e8c-adc5-5ac91ae7fa18_6/predicted_true'}
# Run ID AutoML_486098d7-6654-4e8c-adc5-5ac91ae7fa18_5
# 	 {'normalized_mean_absolute_error': 0.03469853818711533}
# 	 {'r2_score': 0.09033370490566599}
# 	 {'mean_absolute_percentage_error': 223387.41520867165}
# 	 {'median_absolute_error': 381554.9429874225}
# 	 {'normalized_median_absolute_error': 0.012061165084900289}
# 	 {'explained_variance': 0.10339635398269205}
# 	 {'mean_absolute_error': 1097688.2139111473}
# 	 {'spearman_correlation': 0.21363747944608713}
# 	 {'root_mean_squared_error': 2777886.88259334}
# 	 {'normalized_root_mean_squared_log_error': 0.08279373052535978}
# 	 {'root_mean_squared_log_error': 1.36454974587277}
# 	 {'normalized_root_mean_squared_error': 0.08781055754594622}
# 	 {'residuals': 'aml://artifactId/ExperimentRun/dcid.AutoML_486098d7-6654-4e8c-adc5-5ac91ae7fa18_5/residuals'}
# 	 {'predicted_true': 'aml://artifactId/ExperimentRun/dcid.AutoML_486098d7-6654-4e8c-adc5-5ac91ae7fa18_5/predicted_true'}
# Run ID AutoML_486098d7-6654-4e8c-adc5-5ac91ae7fa18_4
# 	 {'normalized_mean_absolute_error': 0.02877532257816794}
# 	 {'r2_score': 0.2268399155185464}
# 	 {'mean_absolute_percentage_error': 32995.362182356985}
# 	 {'median_absolute_error': 314897.9375}
# 	 {'normalized_median_absolute_error': 0.009954099871816655}
# 	 {'explained_variance': 0.23194335850913558}
# 	 {'mean_absolute_error': 910307.2952299558}
# 	 {'spearman_correlation': 0.27762891363651115}
# 	 {'root_mean_squared_error': 2577017.3109011613}
# 	 {'normalized_root_mean_squared_log_error': 0.07445561897454628}
# 	 {'root_mean_squared_log_error': 1.227126683455787}
# 	 {'normalized_root_mean_squared_error': 0.08146095807347277}
# 	 {'residuals': 'aml://artifactId/ExperimentRun/dcid.AutoML_486098d7-6654-4e8c-adc5-5ac91ae7fa18_4/residuals'}
# 	 {'predicted_true': 'aml://artifactId/ExperimentRun/dcid.AutoML_486098d7-6654-4e8c-adc5-5ac91ae7fa18_4/predicted_true'}
# Run ID AutoML_486098d7-6654-4e8c-adc5-5ac91ae7fa18_3
# 	 {'normalized_mean_absolute_error': 0.022719926790509614}
# 	 {'r2_score': 0.1921647914417548}
# 	 {'mean_absolute_percentage_error': 112608.51839630371}
# 	 {'median_absolute_error': 129130.1515625}
# 	 {'normalized_median_absolute_error': 0.0040818762908408895}
# 	 {'explained_variance': 0.1980251801705863}
# 	 {'mean_absolute_error': 718744.8567538594}
# 	 {'spearman_correlation': 0.5276304237320494}
# 	 {'root_mean_squared_error': 2424938.8830154147}
# 	 {'normalized_root_mean_squared_log_error': 0.06355873815176671}
# 	 {'root_mean_squared_log_error': 1.0475317326886489}
# 	 {'normalized_root_mean_squared_error': 0.07665367393708941}
# 	 {'residuals': 'aml://artifactId/ExperimentRun/dcid.AutoML_486098d7-6654-4e8c-adc5-5ac91ae7fa18_3/residuals'}
# 	 {'predicted_true': 'aml://artifactId/ExperimentRun/dcid.AutoML_486098d7-6654-4e8c-adc5-5ac91ae7fa18_3/predicted_true'}
# Run ID AutoML_486098d7-6654-4e8c-adc5-5ac91ae7fa18_2
# 	 {'normalized_mean_absolute_error': 0.04014480832780513}
# 	 {'r2_score': 0.021105150802340857}
# 	 {'mean_absolute_percentage_error': 144114.3117249131}
# 	 {'median_absolute_error': 637524.8678855955}
# 	 {'normalized_median_absolute_error': 0.02015251753022338}
# 	 {'explained_variance': 0.03251109843707316}
# 	 {'mean_absolute_error': 1269980.9632763453}
# 	 {'spearman_correlation': 0.1472545302812427}
# 	 {'root_mean_squared_error': 2833877.5877510738}
# 	 {'normalized_root_mean_squared_log_error': nan}
# 	 {'root_mean_squared_log_error': nan}
# 	 {'normalized_root_mean_squared_error': 0.08958045504180875}
# 	 {'residuals': 'aml://artifactId/ExperimentRun/dcid.AutoML_486098d7-6654-4e8c-adc5-5ac91ae7fa18_2/residuals'}
# 	 {'predicted_true': 'aml://artifactId/ExperimentRun/dcid.AutoML_486098d7-6654-4e8c-adc5-5ac91ae7fa18_2/predicted_true'}
# Run ID AutoML_486098d7-6654-4e8c-adc5-5ac91ae7fa18_1
# 	 {'normalized_mean_absolute_error': 0.02542855741818702}
# 	 {'r2_score': 0.33987536343375}
# 	 {'mean_absolute_percentage_error': 98844.42542330452}
# 	 {'median_absolute_error': 202778.340625}
# 	 {'normalized_median_absolute_error': 0.006409936725681178}
# 	 {'explained_variance': 0.3430899719348708}
# 	 {'mean_absolute_error': 804432.3834100773}
# 	 {'spearman_correlation': 0.38009550193911135}
# 	 {'root_mean_squared_error': 2323030.250510406}
# 	 {'normalized_root_mean_squared_log_error': 0.07410940824447905}
# 	 {'root_mean_squared_log_error': 1.2214206745498717}
# 	 {'normalized_root_mean_squared_error': 0.07343228508389911}
# 	 {'residuals': 'aml://artifactId/ExperimentRun/dcid.AutoML_486098d7-6654-4e8c-adc5-5ac91ae7fa18_1/residuals'}
# 	 {'predicted_true': 'aml://artifactId/ExperimentRun/dcid.AutoML_486098d7-6654-4e8c-adc5-5ac91ae7fa18_1/predicted_true'}
# Run ID AutoML_486098d7-6654-4e8c-adc5-5ac91ae7fa18_0
# 	 {'normalized_mean_absolute_error': 0.029577827997701246}
# 	 {'r2_score': 0.2595182098398854}
# 	 {'mean_absolute_percentage_error': 84302.9755497813}
# 	 {'median_absolute_error': 290743.4236110888}
# 	 {'normalized_median_absolute_error': 0.00919056218238544}
# 	 {'explained_variance': 0.26485948020838224}
# 	 {'mean_absolute_error': 935694.5532138853}
# 	 {'spearman_correlation': 0.3079250154773455}
# 	 {'root_mean_squared_error': 2390783.173999677}
# 	 {'normalized_root_mean_squared_log_error': nan}
# 	 {'root_mean_squared_log_error': nan}
# 	 {'normalized_root_mean_squared_error': 0.07557399287777679}
# 	 {'residuals': 'aml://artifactId/ExperimentRun/dcid.AutoML_486098d7-6654-4e8c-adc5-5ac91ae7fa18_0/residuals'}
# 	 {'predicted_true': 'aml://artifactId/ExperimentRun/dcid.AutoML_486098d7-6654-4e8c-adc5-5ac91ae7fa18_0/predicted_true'}
# Run ID AutoML_486098d7-6654-4e8c-adc5-5ac91ae7fa18_featurize
# Run ID AutoML_486098d7-6654-4e8c-adc5-5ac91ae7fa18_setup

# %% [markdown]
# ## Get the best run
#
# You can retrieve the best-performing run, and view its details like this:

# %%
best_run, fitted_model = automl_run.get_output()
print(best_run)
print('\nBest Model Definition:')
print(fitted_model)
print('\nBest Run Transformations:')
for step in fitted_model.named_steps:
    print(step)
print('\nBest Run Metrics:')
best_run_metrics = best_run.get_metrics()
for metric_name in best_run_metrics:
    metric = best_run_metrics[metric_name]
    print(metric_name, metric)
# Out:
# Run(Experiment: mslearn-house-automl-sdk,
# Id: AutoML_486098d7-6654-4e8c-adc5-5ac91ae7fa18_30,
# Type: azureml.scriptrun,
# Status: Completed)
#
# Best Model Definition:
# RegressionPipeline(pipeline=Pipeline(memory=None,
#                                      steps=[('datatransformer',
#                                              DataTransformer(enable_dnn=False, enable_feature_sweeping=True, feature_sweeping_config={}, feature_sweeping_timeout=86400, featurization_config=None, force_text_dnn=False, is_cross_validation=True, is_onnx_compatible=False, observer=None, task='regression', working_dir='/mnt/batch/ta...
# ), random_state=0, reg_alpha=2.3958333333333335, reg_lambda=1.7708333333333335, subsample=1, tree_method='auto'))], verbose=False)), ('17', Pipeline(memory=None, steps=[('maxabsscaler', MaxAbsScaler(copy=True)), ('decisiontreeregressor', DecisionTreeRegressor(ccp_alpha=0.0, criterion='mse', max_depth=None, max_features=0.9, max_leaf_nodes=None, min_impurity_decrease=0.0, min_impurity_split=None, min_samples_leaf=0.00218714609400816, min_samples_split=0.0037087774117744725, min_weight_fraction_leaf=0.0, presort='deprecated', random_state=None, splitter='best'))], verbose=False)), ('12', Pipeline(memory=None, steps=[('maxabsscaler', MaxAbsScaler(copy=True)), ('extratreesregressor', ExtraTreesRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mae', max_depth=None, max_features=0.8, max_leaf_nodes=None, max_samples=None, min_impurity_decrease=0.0, min_impurity_split=None, min_samples_leaf=0.01091729022778783, min_samples_split=0.001529732116091358, min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=1, oob_score=False, random_state=None, verbose=0, warm_start=False))], verbose=False))], weights=[0.06666666666666667, 0.06666666666666667, 0.06666666666666667, 0.26666666666666666, 0.4666666666666667, 0.06666666666666667]))],
#                                      verbose=False),
#                    stddev=[2472902.6566388463])
#
# Best Run Transformations:
# datatransformer
# prefittedsoftvotingregressor
#
# Best Run Metrics:
# r2_score 0.2854655467465753
# root_mean_squared_log_error 1.0074004589163956
# normalized_median_absolute_error 0.004078531758350637
# mean_absolute_error 732218.3787327859
# spearman_correlation 0.5453013597820174
# explained_variance 0.2883179643232707
# normalized_mean_absolute_error 0.02314583235365212
# normalized_root_mean_squared_error 0.07553715390332427
# root_mean_squared_error 2389617.7730870782
# normalized_root_mean_squared_log_error 0.061123782682837136
# median_absolute_error 129024.34728118428
# mean_absolute_percentage_error 97379.71853308132
# predicted_true aml://artifactId/ExperimentRun/dcid.AutoML_486098d7-6654-4e8c-adc5-5ac91ae7fa18_30/predicted_true
# residuals aml://artifactId/ExperimentRun/dcid.AutoML_486098d7-6654-4e8c-adc5-5ac91ae7fa18_30/residuals

# %% [markdown]
# Finally, having found the best performing model, you can register it.

# %%
from azureml.core import Model

# Register model
best_run.register_model(model_path='outputs/model.pkl', model_name='diabetes_model',
                        tags={'Training context':'Auto ML'},
                        properties={'AUC': best_run_metrics['AUC_weighted'], 'Accuracy': best_run_metrics['accuracy']})

# List registered models
for model in Model.list(ws):
    print(model.name, 'version:', model.version)
    for tag_name in model.tags:
        tag = model.tags[tag_name]
        print ('\t',tag_name, ':', tag)
    for prop_name in model.properties:
        prop = model.properties[prop_name]
        print ('\t',prop_name, ':', prop)
    print('\n')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-10-e7984738f1e5> in <module>
#       4 best_run.register_model(model_path='outputs/model.pkl', model_name='diabetes_model',
#       5                         tags={'Training context':'Auto ML'},
# ----> 6                         properties={'AUC': best_run_metrics['AUC_weighted'], 'Accuracy': best_run_metrics['accuracy']})
#       7
#       8 # List registered models
#
# KeyError: 'AUC_weighted'

# %% [markdown]
# > **More Information**: For more information Automated Machine Learning, see the [Azure ML documentation](https://docs.microsoft.com/azure/machine-learning/how-to-configure-auto-train).
